# %%
import numpy as np
g = 9.8
v0 = 4 #input("v0: ")
x0 = 0 #input("x0: ")
y0 = 0 #input("y0: ")
D = 0.95

v0x = v0*(np.cos(np.pi/4))
v0y = v0*(np.sin(np.pi/4))
v = (v0x**2 + v0y**2)**0.5
ax = -D*v*v0x
ay = -g - D*v*v0y

height = []
xRange = []

deltaT=0.01

yCutOff = y0

while y0>=yCutOff:
    height.append(y0)
    xRange.append(x0)
    
    y0+=v0y*deltaT + 0.5*ay*deltaT**2
    v0y+=ay*deltaT
    x0+= v0x*deltaT + 0.5*ax*deltaT**2
    v0x+=ax*deltaT
    
import matplotlib.pyplot as plt
plt.plot (xRange,height , 'r')

# %%
import numpy as np
g = 9.8
v0 = 4 #input("v0: ")
x0 = 0 #input("x0: ")
y0 = 0 #input("y0: ")
D = 0.95
v0x = v0*(np.cos(np.pi/4))
v0y = v0*(np.sin(np.pi/4))
v = (v0x**2 + v0y**2)**0.5
ax = -D*v0x
ay = -g - D*v0y

height = []
xRange = []

deltaT=0.01

yCutOff = y0

while y0>=yCutOff:
    height.append(y0)
    xRange.append(x0)
    
    y0+=v0y*deltaT + 0.5*ay*deltaT**2
    v0y+=ay*deltaT
    x0+= v0x*deltaT + 0.5*ax*deltaT**2
    v0x+=ax*deltaT
    
import matplotlib.pyplot as plt
plt.plot (xRange,height , 'r')

# %%
import numpy as np
g = 9.8
v0 = 4 #input("v0: ")
x0 = 0 #input("x0: ")
y0 = 0 #input("y0: ")
D = 0.5

v0x = v0*(np.cos(np.pi/4))
v0y = v0*(np.sin(np.pi/4))
v = (v0x**2 + v0y**2)**0.5
ax = -D*v*v0x
ay = -g - D*v*v0y

height = []
xRange = []

deltaT=0.01

yCutOff = y0

while y0>=yCutOff:
    height.append(y0)
    xRange.append(x0)
    
    y0+= v0y*deltaT - 0.5*g*deltaT**2
    v0y+=-g*deltaT
    x0+= v0x*deltaT 
    
import matplotlib.pyplot as plt
plt.plot (xRange,height , 'r')

# %%
import numpy as np
import matplotlib.pyplot as plt

g = 9.8
v0 = 4 #input("v0: ")
x0 = 0 #input("x0: ")
y0 = 0 #input("y0: ")
D = 0.45

v0x = v0*(np.cos(np.pi/3))
v0y = v0*(np.sin(np.pi/3))

height = []
xRange = []

deltaT=0.01

yCutOff = y0

while y0>=yCutOff:
    height.append(y0)
    xRange.append(x0)
    
    y0+= v0y*deltaT - 0.5*g*deltaT**2
    v0y+=-g*deltaT
    x0+= v0x*deltaT 
    
    

#drag-power1
g = 9.8
v0 = 4 #input("v0: ")
x0 = 0 #input("x0: ")
y0 = 0 #input("y0: ")
D = 0.45

v0x = v0*(np.cos(np.pi/3))
v0y = v0*(np.sin(np.pi/3))
ax1 = -D*v0x
ay1 = -D*v0y - g

height1 = []
xRange1 = []

deltaT=0.01

yCutOff = y0

while y0>=yCutOff:
    height1.append(y0)
    xRange1.append(x0)
    
    y0+= v0y*deltaT + 0.5*ay1*deltaT**2
    v0y+=ay1*deltaT
    x0+= v0x*deltaT + 0.5*ax1*deltaT**2
    v0x+=ax1*deltaT


#drag-power2
g = 9.8
v0 = 4 #input("v0: ")
x0 = 0 #input("x0: ")
y0 = 0 #input("y0: ")
D = 0.45

v0x = v0*(np.cos(np.pi/3))
v0y = v0*(np.sin(np.pi/3))
v = (v0x**2 + v0y**2)**0.5
ax = -D*v*v0x
ay = -g - D*v*v0y

height2 = []
xRange2 = []

deltaT=0.01

yCutOff = y0

while y0>=yCutOff:
    height2.append(y0)
    xRange2.append(x0)
    
    y0+=v0y*deltaT + 0.5*ay*deltaT**2
    v0y+=ay*deltaT
    x0+= v0x*deltaT + 0.5*ax*deltaT**2
    v0x+=ax*deltaT
    
plt.plot (xRange,height , 'r' , label = "Fr=0")
plt.plot (xRange1,height1 , 'b', label = "Fr=kv")
plt.plot (xRange2,height2 , 'g' , label = "Fr=kv^2")
plt.xlabel("x axes")
plt.ylabel("y axes")
plt.title("Projectile")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

xRange = []
yRange = []

A = 1
B = 1
wx= np.pi/0.25
wy= (3/4)*wx

t = np.arange(0,10,0.001)

for i in range(len(t)):
    x = A*np.cos(wx*t[i]+np.pi/2)
    y = A*np.cos(wy*t[i]+np.pi/2)
    xRange.append(x)
    yRange.append(y)
    
    
plt.plot(xRange,yRange)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

xRange = []
yRange = []


A=1
betha = 3.5
w1=((np.pi/3)*(np.pi/3)-(betha)**2)**0.5
alpha=np.pi/2
k=200

t = np.arange(0,10,0.0001)

for i in range(len(t)):
    zarib = (A**2)/2*(np.exp(-2*betha*t[i]))
    z = k/(w1**2+betha**2)
    x = (w1**2)*(np.cos(w1*t[i]-alpha))*(np.cos(w1*t[i]-alpha)) + (betha**2)*(np.sin(w1*t[i]-alpha))*(np.sin(w1*t[i]-alpha))
    y=2*w1*betha*(np.sin(w1*t[i])*(np.cos(w1*t[i] - alpha)))
    felan1 = z*(x - y)
    felan2 = k*(np.sin(w1*t[i]-alpha))*(np.sin(w1*t[i]-alpha))
    E= zarib*(felan1 + felan2)
    xRange.append(t[i])
    yRange.append(E)
    
plt.plot(xRange , yRange)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

A = 1
betha = 0.4
alpha = np.pi/2
w0=np.pi/0.5
w1 = (w0**2 - betha**2)**0.5
t = np.arange(0,10,0.001)
xRange=[]
yRange=[]
for i in range(len(t)):
    x = A*np.exp(-betha*t[i])*(np.sin(w1*t[i] - alpha))
    xRange.append(i)
    yRange.append(x)
    
plt.plot(xRange , yRange)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def osi(t):
    A = 1
    betha = 0.4
    alpha = np.pi/2
    w0=np.pi/0.5
    w1 = (w0**2 - betha**2)**0.5
    x = A*np.exp(-betha*t)*(np.sin(w1*t- alpha))
    return x

t = np.arange(0,10,0.001)
plt.plot(t , osi(t))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

A = 1
betha = 0.5
alpha = np.pi
w0=np.pi/2.5
w1 = (w0**2 - betha**2)**0.5
t = np.arange(0,10,0.001)
xRange=[]
yRange=[]

for i in range(len(t)):
    x = A*np.exp(-betha*t[i])*(np.sin(w1*t[i] - alpha))
    xdot = (-betha)*A*np.exp(-betha*t[i])*(np.sin(w1*t[i] - alpha)) + A*w1*np.exp(-betha*t[i])*np.cos(w1*t[i] - alpha)
    xRange.append(x)
    yRange.append(xdot)
    
plt.plot(xRange , yRange)
plt.plot(range(1))
plt.xlim(-0.5, 0.5)
plt.ylim(-0.5, 0.5)
plt.draw()

# %%
import numpy as np
import matplotlib.pyplot as plt

A = 1
betha = 0.5
alpha = np.pi/2
w0=np.pi
w1 = (w0**2 - betha**2)**0.5
t = np.arange(0,10,0.001)
theta_list = []
r_list = []

for i in range(len(t)):
    x = A*np.exp(-betha*t[i])*(np.sin(w1*t[i] - alpha))
    xdot = (-betha)*A*np.exp(-betha*t[i])*(np.sin(w1*t[i] - alpha)) + A*w1*np.exp(-betha*t[i])*np.cos(w1*t[i] - alpha)
    u = w1*x
    w = betha*x + xdot
    theta = w1*t[i]
    r = A*w1*np.exp((-betha/w1)*(w1*t[i]))
    theta_list.append(theta)
    r_list.append(r)
    
    


fig = plt.figure()

ax = fig.add_subplot(polar=True)

ax.plot(theta_list,r_list)

# %%
#SHM phase plane
import matplotlib.pyplot as plt
import numpy as np

w = 1
t = np.arange(0,10,0.001)

xRange = []
yRange = []

for i in range(len(t)):
    x = np.cos(w*t[i])
    xdot = -w*(np.sin(w*t[i]))
    xRange.append(x)
    yRange.append(xdot)
    
plt.plot(xRange,yRange)

# %%
import matplotlib.pyplot as plt
import numpy as np
x = 0
a = 100
b = 1
xRange = []
yRange = []
dx = 0.1
while x<50:
    x+=dx
    y+=((a**2)*(1 + ((x**2)/b**2)))**0.5
    xRange.append(x)
    yRange.append(y)
    
plt.plot(xRange,yRange)
plt.xlim(-50, 50)
# Out:
# (-50.0, 50.0)

# %%
#pendulum phase plane
from pylab import *

#thetadot = omega
#omegadot = -g/L*sin(theta)

g,L = 1,1
omega, yvalues = meshgrid(arange(-8, 8, 0.1), arange(-3, 3, 0.1))
xdot = yvalues
ydot = -g/L*sin(omega)
streamplot(omega, yvalues, xdot, ydot)
grid()

# %%
import numpy as np
import matplotlib.pyplot as plt

F0 = 2
A = 2
betha = 0.15
alpha = np.pi
w0=np.pi
w1 = (w0**2 - betha**2)**0.5
w = 1/2*w1
t = np.arange(0,50,0.001)
xRange=[]
yRange=[]
for i in range(len(t)):
    xc = A*np.exp(-betha*t[i])*(np.cos(w1*t[i] - alpha))
    felan = w0**2 - w**2 + 4*(betha**2)*(w**2)
    xp = F0*np.cos(w*t[i])/(felan**0.5)
    xRange.append(t[i])
    yRange.append(xc+xp)

x1Range=[]
y1Range=[]
for i in range(len(t)):
    felan = w0**2 - w**2 + 4*(betha**2)*(w**2)
    xp = F0*np.cos(w*t[i])/(felan**0.5)
    x1Range.append(t[i])
    y1Range.append(xp)
    
plt.plot(xRange , yRange)
#plt.plot(x1Range , y1Range,'--')  
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=0.1
vx=1
ax= -(w0**2)*x - 2*betha*vx
m = 2
k = 200
betha = 0.4/(2*m)
w0=(k/m)**0.5
t = np.arange(0,100,0.01)
xRange=[]
yRange=[]
for i in range(len(t)):
    x+= vx*t[i]
    vx+= ax*t[i]
    xRange.append(i)
    yRange.append(x)
    

plt.plot(xRange , yRange)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

A = 1
betha = 0.15
w0=np.pi
w = np.arange(0,np.pi/0.05, 0.01)
xRange=[]
yRange=[]
for i in range(len(w)):
    felan = w0**2 -(w[i])**2 + 4*(betha**2)*((w[i])**2)
    D = A/(felan**0.5)
    xRange.append(i)
    yRange.append(D)
    
import numpy as np
import matplotlib.pyplot as plt

A = 1
betha = 0.15
w0=np.pi/2
w = np.arange(0,np.pi/0.05, 0.01)
x1Range=[]
y1Range=[]
for i in range(len(w)):
    felan = w0**2 -(w[i])**2 + 4*(betha**2)*((w[i])**2)
    D = A/(felan**0.5)
    x1Range.append(i)
    y1Range.append(D)
    
import numpy as np
import matplotlib.pyplot as plt

A = 1
betha = 0.15
w0=np.pi/4
w = np.arange(0,np.pi/0.05, 0.01)
x2Range=[]
y2Range=[]
for i in range(len(w)):
    felan = w0**2 -(w[i])**2 + 4*(betha**2)*((w[i])**2)
    D = A/(felan**0.5)
    x2Range.append(i)
    y2Range.append(D)
    
A = 9
betha = 0.9
w0= np.pi/4
w = np.arange(0,np.pi/0.02, 0.01)
x3Range=[]
y3Range=[]
for i in range(len(w)):
    felan = w0**2 -(w[i])**2 + 4*(betha**2)*((w[i])**2)
    D = A/(felan**0.5)
    x3Range.append(w[i])
    y3Range.append(D)

plt.plot(xRange , yRange)
plt.plot(x1Range , y1Range)
plt.plot(x2Range , y2Range)
plt.plot(x3Range , y3Range)
# Out:
# <ipython-input-54-b77e5f5b8a0e>:12: RuntimeWarning: invalid value encountered in double_scalars
#   D = A/(felan**0.5)
# <ipython-input-54-b77e5f5b8a0e>:27: RuntimeWarning: invalid value encountered in double_scalars
#   D = A/(felan**0.5)
# <ipython-input-54-b77e5f5b8a0e>:42: RuntimeWarning: invalid value encountered in double_scalars
#   D = A/(felan**0.5)
